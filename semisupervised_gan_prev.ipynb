# %% [markdown]
# ## Imports

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torchvision.utils as vutils

# %% [markdown]
# ## Data loaders

# %% [markdown]
# ### SVHN Dataset

# %%
class SvhnDataset(Dataset):
    def __init__(self, image_size, split):
        self.split = split
        self.use_gpu = True if torch.cuda.is_available() else False

        self.svhn_dataset = self._create_dataset(image_size, split)
        self.label_mask = self._create_label_mask()

    def _create_dataset(self, image_size, split):
        normalize = transforms.Normalize(
            mean=[0.5, 0.5, 0.5],
            std=[0.5, 0.5, 0.5])
        transform = transforms.Compose([
            transforms.Resize(image_size),
            transforms.ToTensor(),
            normalize])
        return datasets.SVHN(root='./svhn', download=True, transform=transform, split=split)

    def _is_train_dataset(self):
        return True if self.split == 'train' else False

    def _create_label_mask(self):
        if self._is_train_dataset():
            label_mask = torch.zeros(len(self.svhn_dataset)).float()
            label_mask[0:1000] = 1
            return label_mask
        return None

    def __len__(self):
        return len(self.svhn_dataset)

    def __getitem__(self, idx):
        data, label = self.svhn_dataset.__getitem__(idx)
        if self._is_train_dataset():
            return data, label, self.label_mask[idx]
        return data, label

# %% [markdown]
# ### Get data loaders

# %%
def get_loader(image_size, batch_size):
    num_workers = 1

    svhn_train = SvhnDataset(image_size=image_size, split='train')
    svhn_test = SvhnDataset(image_size=image_size, split='test')

    svhn_loader_train = DataLoader(
        dataset=svhn_train,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers
    )

    svhn_loader_test = DataLoader(
        dataset=svhn_test,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers
    )

    return svhn_loader_train, svhn_loader_test

# %%
svhn_loader_train, _ = get_loader(image_size=32, batch_size=36)
image_iter = iter(svhn_loader_train)
images, _, _ = image_iter.next()
# Out:
# Using downloaded and verified file: ./svhn/train_32x32.mat
# Using downloaded and verified file: ./svhn/test_32x32.mat

# %%
def view_images(images):
    assert(len(images) >= 36)
    fig, axes = plt.subplots(6, 6, sharex=True, sharey=True, figsize=(5,5))
    for idx, ax in enumerate(axes.flatten()):
        img = images[idx].numpy()
        img = img.transpose(1, 2, 0)
        img = ((img - img.min())*255 / (img.max() - img.min())).astype(np.uint8)
        ax.imshow(img, aspect='equal')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
    plt.subplots_adjust(wspace=0, hspace=0)

# %%
view_images(images)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Conv, deconv helpers

# %%
def deconv(c_in, c_out, k_size, stride=2, pad=1, bn=True):
    layers = []
    layers.append(nn.ConvTranspose2d(c_in, c_out, k_size, stride, pad, bias=False))
    if bn:
        layers.append(nn.BatchNorm2d(c_out))
    return nn.Sequential(*layers)

def conv(c_in, c_out, k_size, stride=2, pad=1, bn=True):
    layers = []
    layers.append(nn.Conv2d(c_in, c_out, k_size, stride, pad, bias=False))
    if bn:
        layers.append(nn.BatchNorm2d(c_out))
    return nn.Sequential(*layers)

# %% [markdown]
# ### GAN logits

# %%
class _ganLogits(nn.Module):
    def __init__(self):
        super(_ganLogits, self).__init__()
    
    def forward(self, class_logits):
        max_val, _ = torch.max(class_logits, 1, keepdim=True)
        stable_class_logits = class_logits - max_val
        max_val = torch.squeeze(max_val)
        gan_logits = torch.log(torch.sum(torch.exp(stable_class_logits), 1)) + max_val
        
        return gan_logits

# %% [markdown]
# ### Generator

# %%
class _netG(nn.Module):
    '''
    GAN generator
    '''
    def __init__(self, nz, ngf, alpha, nc, use_gpu):
        super(_netG, self).__init__()
        self.use_gpu = use_gpu
        
        self.main = nn.Sequential(
            # noise is going into a convolution
            nn.ConvTranspose2d(nz, ngf * 4, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.LeakyReLU(alpha),
            # (ngf * 4) x 4 x 4
            nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.LeakyReLU(alpha),
            # (ngf * 2) x 8 x 8
            nn.ConvTranspose2d(ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.LeakyReLU(alpha),
            # (ngf) x 16 x 16
            nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
            # (nc) x 32 x 32
        )

    def forward(self, inputs):
        if isinstance(inputs.data, torch.cuda.FloatTensor) and self.use_gpu:
            out = nn.parallel.data_parallel(self.main, inputs, range(1))
        else:
            out = self.main(inputs)
        return out

# %% [markdown]
# ### Discriminator

# %%
class _netD(nn.Module):
    '''
    GAN discruminator
    '''
    def __init__(self, ndf, alpha, nc, drop_rate, num_classes, use_gpu):
        super(_netD, self).__init__()
        self.use_gpu = use_gpu
        
        self.main = nn.Sequential(
            nn.Dropout2d(drop_rate/2.5),
            
            # input is (number_channels) x 32 x 32
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(alpha),
            nn.Dropout2d(drop_rate),
            # (ndf) x 16 x 16
            nn.Conv2d(ndf, ndf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf),
            nn.LeakyReLU(alpha),
            # (ndf) x 8 x 8
            nn.Conv2d(ndf, ndf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf),
            nn.LeakyReLU(alpha),
            nn.Dropout2d(drop_rate),
            # (ndf) x 4 x 4
            nn.Conv2d(ndf, ndf * 2, 3, 1, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(alpha),
            # (ndf * 2) x 4 x 4
            nn.Conv2d(ndf * 2, ndf * 2, 3, 1, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(alpha),
            # (ndf * 2) x 4 x 4
            nn.Conv2d(ndf * 2, ndf * 2, 3, 1, 0, bias=False),
            nn.LeakyReLU(alpha),
            # (ndf * 2) x 2 x 2
        )
        
        self.features = nn.AvgPool2d(kernel_size=2)

        self.class_logits = nn.Linear(
            in_features=(ndf * 2) * 1 * 1,
            out_features=num_classes)
        
        self.gan_logits = _ganLogits()
        
        self.softmax = nn.Softmax(dim=0)

    def forward(self, inputs):
        if isinstance(inputs.data, torch.cuda.FloatTensor) and self.use_gpu:
            out = nn.parallel.data_parallel(self.main, inputs, range(1))
        else:
            out = self.main(inputs)

        features = self.features(out)
        features = features.squeeze()

        class_logits = self.class_logits(features)

        gan_logits = self.gan_logits(class_logits)
        
        out = self.softmax(class_logits)

        return out, class_logits, gan_logits, features

# %% [markdown]
# ## Solver

# %%
import torch
import torch.nn as nn
from torch import optim
from torch.autograd import Variable
import numpy as np
import os

class Solver:
    def __init__(self, svhn_loader_train, svhn_loader_test, batch_size):
        self.nz = 100
        self.nc = 3
        self.lrelu_alpha = 0.2
        self.drop_rate = .5
        self.g_size_mult = 32
        self.d_size_mult = 64
        self.num_classes = 10
        self.use_gpu = True if torch.cuda.is_available() else False
        self.learning_rate = 0.0002
        self.beta1 = .5
        self.svhn_loader_train = svhn_loader_train
        self.svhn_loader_test = svhn_loader_test
        self.epochs = 25
        self.batch_size = batch_size
        self.out_dir = './train_out'

        self.generator, self.discriminator = self._build_model()
        self.g_optimizer, self.d_optimizer = self._create_optimizers()

    def _build_model(self):
        generator = _netG(
            self.nz, self.g_size_mult, self.lrelu_alpha,
            self.nc, self.use_gpu)
        generator.apply(self._weights_init)
        print(generator)
        # TODO: load weights from file if it exists

        discriminator = _netD(
            self.d_size_mult, self.lrelu_alpha, self.nc,
            self.drop_rate, self.num_classes, self.use_gpu)
        discriminator.apply(self._weights_init)
        print(discriminator)
        # TODO: load weights from file if it exists

        if self.use_gpu:
            generator = generator.cuda()
            discriminator = discriminator.cuda()

        return generator, discriminator

    def _weights_init(self, module):
        '''
        Custom weights initialization called on generator and discriminator
        '''
        classname = module.__class__.__name__
        if classname.find('Conv') != -1:
            module.weight.data.normal_(0.0, 0.02)
        elif classname.find('BatchNorm') != -1:
            module.weight.data.normal_(1.0, 0.02)
            module.bias.data.fill_(0)

    def _create_optimizers(self):
        g_params = list(self.generator.parameters())
        d_params = list(self.discriminator.parameters())

        g_optimizer = optim.Adam(g_params, self.learning_rate, betas=(self.beta1, 0.999))
        d_optimizer = optim.Adam(d_params, self.learning_rate, betas=(self.beta1, 0.999))

        return g_optimizer, d_optimizer

    def _to_var(self, x):
        if self.use_gpu:
            x = x.cuda()
        return Variable(x)

    def _one_hot(self, x):
        ones = torch.sparse.torch.eye(self.num_classes)
        one_hot = ones.index_select(0, x.data.cpu())
        if self.use_gpu:
            one_hot = one_hot.cuda()
        return Variable(one_hot)

    def train(self):
        if not os.path.exists(self.out_dir):
            os.makedirs(self.out_dir)
        
        d_gan_criterion = nn.BCEWithLogitsLoss()
        
        noise = torch.FloatTensor(self.batch_size, self.nz, 1, 1)
        
        fixed_noise = torch.FloatTensor(self.batch_size, self.nz, 1, 1).normal_(0, 1)
        fixed_noise = self._to_var(fixed_noise)
        
        d_gan_labels_real = torch.LongTensor(batch_size)
        d_gan_labels_fake = torch.LongTensor(batch_size)

        for epoch in range(1, self.epochs + 1):
            masked_correct = 0
            num_samples = 0
            
            for i, data in enumerate(self.svhn_loader_train):
                # load svhn dataset
                svhn_data, svhn_labels, label_mask = data
                svhn_data = self._to_var(svhn_data)
                svhn_labels = self._to_var(svhn_labels).long().squeeze()
                label_mask = self._to_var(label_mask).float().squeeze()

                # -------------- train discriminator --------------

                # train with real images
                self.d_optimizer.zero_grad()

                # d_out == softmax(d_class_logits)
                d_out, d_class_logits_on_data, d_gan_logits_real, _ = self.discriminator(svhn_data)
                d_gan_labels_real.resize_as_(svhn_labels.data.cpu()).fill_(1)
                d_gan_labels_real_var = self._to_var(d_gan_labels_real).float()
                d_gan_loss_real = d_gan_criterion(
                    d_gan_logits_real,
                    d_gan_labels_real_var)

                # train with fake images
                noise.resize_(batch_size, self.nz, 1, 1).normal_(0, 1)
                noise_var = self._to_var(noise)
                fake = self.generator(noise_var)

                # call detach() to avoid backprop for generator here
                _, _, d_gan_logits_fake, _ = self.discriminator(fake.detach())
                d_gan_labels_fake.resize_(batch_size).fill_(0)
                d_gan_labels_fake_var = self._to_var(d_gan_labels_fake).float()
                d_gan_loss_fake = d_gan_criterion(
                    d_gan_logits_fake,
                    d_gan_labels_fake_var)

                d_gan_loss = d_gan_loss_real + d_gan_loss_fake

                # d_out == softmax(d_class_logits)
                # see https://stackoverflow.com/questions/34240703/whats-the-difference-between-softmax-and-softmax-cross-entropy-with-logits/39499486#39499486
                svhn_labels_one_hot = self._one_hot(svhn_labels)
                d_class_loss_entropy = -torch.sum(svhn_labels_one_hot * torch.log(d_out), dim=1)
                
                # d_class_loss_entropy = d_class_criterion(
                #     d_class_logits_on_data,
                #     self._one_hot(svhn_labels)
                # )

                d_class_loss_entropy = d_class_loss_entropy.squeeze()
                delim = torch.max(torch.Tensor([1.0, torch.sum(label_mask.data)]))
                d_class_loss = torch.sum(label_mask * d_class_loss_entropy) / delim
                
                d_loss = d_gan_loss + d_class_loss
                d_loss.backward()
                self.d_optimizer.step()

                # -------------- update generator --------------
                
                self.g_optimizer.zero_grad()

                # call discriminator again to do backprop for generator here
                _, _, _, d_data_features = self.discriminator(fake)
                _, _, _, d_sample_features = self.discriminator(svhn_data.detach())
                
                # Here we set `g_loss` to the "feature matching" loss invented by Tim Salimans at OpenAI.
                # This loss consists of minimizing the absolute difference between the expected features
                # on the data and the expected features on the generated samples.
                # This loss works better for semi-supervised learning than the tradition GAN losses.
                data_features_mean = torch.mean(d_data_features, dim=0)
                sample_features_mean = torch.mean(d_sample_features, dim=0)
                
                g_loss = torch.mean(torch.abs(data_features_mean - sample_features_mean))

                g_loss.backward()
                self.g_optimizer.step()

                _, pred_class = torch.max(d_class_logits_on_data, 1)
                eq = torch.eq(svhn_labels, pred_class)
                correct = torch.sum(eq.float())
                masked_correct += torch.sum(label_mask * eq.float())
                num_samples += torch.sum(label_mask)
                
                if i % 200 == 0:
                    print('Training:\tepoch {}/{}\tdiscr. gan loss {}\tdiscr. class loss {}\tgen loss {}\tsamples {}/{}'.
                        format(epoch, self.epochs, d_gan_loss.data[0], d_class_loss.data[0], g_loss.data[0], 
                               i + 1, len(self.svhn_loader_train)))
                    real_cpu, _, _ = data
                    vutils.save_image(real_cpu,
                            '%s/real_samples.png' % self.out_dir,
                            normalize=True)
                    fake = self.generator(fixed_noise)
                    vutils.save_image(fake.data,
                            '%s/fake_samples_epoch_%03d.png' % (self.out_dir, epoch),
                            normalize=True)
                    
            # accuracy = masked_correct.data[0]/max(1.0, num_samples.data[0])
            print('Training:\tepoch {}/{}\taccuracy {}/{}'.format(epoch, self.epochs, masked_correct.data, num_samples.data))

            correct = 0
            num_samples = 0
            for i, data in enumerate(self.svhn_loader_test):
                # load svhn dataset
                svhn_data, svhn_labels = data
                svhn_data = self._to_var(svhn_data)
                svhn_labels = self._to_var(svhn_labels).long().squeeze()

                # -------------- train discriminator --------------

                # train with real images
                d_out, d_class_logits, _, _ = self.discriminator(svhn_data)
                _, pred_idx = torch.max(d_class_logits.data, 1)
                eq = torch.eq(svhn_labels.data, pred_idx)
                correct += torch.sum(eq.float())
                num_samples += len(svhn_labels)
                
                if i % 50 == 0:
                    print('Test:\tepoch {}/{}\tsamples {}/{}'.format(
                        epoch, self.epochs, i + 1, len(self.svhn_loader_test)))
                
            # accuracy = correct/max(1.0, 1.0 * num_samples)
            print('Test:\tepoch {}/{}\taccuracy {}/{}'.format(epoch, self.epochs, correct, num_samples))

            # do checkpointing
            torch.save(self.generator.state_dict(), '%s/netG_epoch_%d.pth' % (self.out_dir, epoch))
            torch.save(self.discriminator.state_dict(), '%s/netD_epoch_%d.pth' % (self.out_dir, epoch))

# %% [markdown]
# ## Main

# %%
image_size = 32
batch_size = 64

# %%
svhn_loader_train, svhn_loader_test = get_loader(image_size, batch_size)
solver = Solver(svhn_loader_train, svhn_loader_test, batch_size)
# Out:
# Using downloaded and verified file: ./svhn/train_32x32.mat
# Using downloaded and verified file: ./svhn/test_32x32.mat
# _netG(
#   (main): Sequential(
#     (0): ConvTranspose2d (100, 128, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (2): LeakyReLU(0.2)
#     (3): ConvTranspose2d (128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (5): LeakyReLU(0.2)
#     (6): ConvTranspose2d (64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True)
#     (8): LeakyReLU(0.2)
#     (9): ConvTranspose2d (32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): Tanh()
#   )
# )
# _netD(
#   (main): Sequential(
#     (0): Dropout2d(p=0.2)
#     (1): Conv2d (3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (2): LeakyReLU(0.2)
#     (3): Dropout2d(p=0.5)
#     (4): Conv2d (64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (6): LeakyReLU(0.2)
#     (7): Conv2d (64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (9): LeakyReLU(0.2)
#     (10): Dropout2d(p=0.5)
#     (11): Conv2d (64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (12): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (13): LeakyReLU(0.2)
#     (14): Conv2d (128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (15): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (16): LeakyReLU(0.2)
#     (17): Conv2d (128, 128, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (18): LeakyReLU(0.2)
#   )
#   (features): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#   (class_logits): Linear(in_features=128, out_features=10)
#   (gan_logits): _ganLogits(
#   )
#   (softmax): Softmax()
# )

# %%
solver.train()
# Out:
# Training:	epoch 1/25	discr. gan loss 2.5258216857910156	discr. class loss 4.299291610717773	gen loss 0.020807962864637375	samples 1/1145
# Training:	epoch 1/25	discr. gan loss 1.4746921062469482	discr. class loss 0.0	gen loss 0.04662320762872696	samples 201/1145
# Training:	epoch 1/25	discr. gan loss 1.3218417167663574	discr. class loss 4.953932285308838	gen loss 0.021470483392477036	samples 401/1145
# Training:	epoch 1/25	discr. gan loss 1.4592516422271729	discr. class loss 4.057962894439697	gen loss 0.016357947140932083	samples 601/1145
# Training:	epoch 1/25	discr. gan loss 1.4202210903167725	discr. class loss 4.368929386138916	gen loss 0.02848963625729084	samples 801/1145
# Training:	epoch 1/25	discr. gan loss 1.2395871877670288	discr. class loss 4.161472797393799	gen loss 0.02892862632870674	samples 1001/1145
# Training:	epoch 1/25	accuracy
#  126
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 1/25	samples 1/407
# Test:	epoch 1/25	samples 51/407
# Test:	epoch 1/25	samples 101/407
# Test:	epoch 1/25	samples 151/407
# Test:	epoch 1/25	samples 201/407
# Test:	epoch 1/25	samples 251/407
# Test:	epoch 1/25	samples 301/407
# Test:	epoch 1/25	samples 351/407
# Test:	epoch 1/25	samples 401/407
# Test:	epoch 1/25	accuracy 3555.0/26032
# Training:	epoch 2/25	discr. gan loss 1.3468286991119385	discr. class loss 4.086379528045654	gen loss 0.03888467699289322	samples 1/1145
# Training:	epoch 2/25	discr. gan loss 1.3790521621704102	discr. class loss 4.298086643218994	gen loss 0.009317348711192608	samples 201/1145
# Training:	epoch 2/25	discr. gan loss 1.2734514474868774	discr. class loss 0.0	gen loss 0.04164319485425949	samples 401/1145
# Training:	epoch 2/25	discr. gan loss 1.3418703079223633	discr. class loss 4.16425895690918	gen loss 0.012058285064995289	samples 601/1145
# Training:	epoch 2/25	discr. gan loss 1.224808931350708	discr. class loss 4.1864519119262695	gen loss 0.025088366121053696	samples 801/1145
# Training:	epoch 2/25	discr. gan loss 1.2031865119934082	discr. class loss 4.0869460105896	gen loss 0.03969118371605873	samples 1001/1145
# Training:	epoch 2/25	accuracy
#  130
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 2/25	samples 1/407
# Test:	epoch 2/25	samples 51/407
# Test:	epoch 2/25	samples 101/407
# Test:	epoch 2/25	samples 151/407
# Test:	epoch 2/25	samples 201/407
# Test:	epoch 2/25	samples 251/407
# Test:	epoch 2/25	samples 301/407
# Test:	epoch 2/25	samples 351/407
# Test:	epoch 2/25	samples 401/407
# Test:	epoch 2/25	accuracy 2889.0/26032
# Training:	epoch 3/25	discr. gan loss 1.4002999067306519	discr. class loss 0.0	gen loss 0.03552241623401642	samples 1/1145
# Training:	epoch 3/25	discr. gan loss 1.4085643291473389	discr. class loss 4.256030559539795	gen loss 0.005609914660453796	samples 201/1145
# Training:	epoch 3/25	discr. gan loss 1.1135683059692383	discr. class loss 4.032078742980957	gen loss 0.08908378332853317	samples 401/1145
# Training:	epoch 3/25	discr. gan loss 1.2962255477905273	discr. class loss 0.0	gen loss 0.07191061973571777	samples 601/1145
# Training:	epoch 3/25	discr. gan loss 1.386669397354126	discr. class loss 4.028966903686523	gen loss 0.006044724956154823	samples 801/1145
# Training:	epoch 3/25	discr. gan loss 1.517320156097412	discr. class loss 0.0	gen loss 0.0203244648873806	samples 1001/1145
# Training:	epoch 3/25	accuracy
#  113
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 3/25	samples 1/407
# Test:	epoch 3/25	samples 51/407
# Test:	epoch 3/25	samples 101/407
# Test:	epoch 3/25	samples 151/407
# Test:	epoch 3/25	samples 201/407
# Test:	epoch 3/25	samples 251/407
# Test:	epoch 3/25	samples 301/407
# Test:	epoch 3/25	samples 351/407
# Test:	epoch 3/25	samples 401/407
# Test:	epoch 3/25	accuracy 2851.0/26032
# Training:	epoch 4/25	discr. gan loss 1.37479567527771	discr. class loss 4.151986122131348	gen loss 0.11149689555168152	samples 1/1145
# Training:	epoch 4/25	discr. gan loss 1.3778345584869385	discr. class loss 3.920180559158325	gen loss 0.020772036164999008	samples 201/1145
# Training:	epoch 4/25	discr. gan loss 1.3925840854644775	discr. class loss 0.0	gen loss 0.02302306890487671	samples 401/1145
# Training:	epoch 4/25	discr. gan loss 1.437517762184143	discr. class loss 4.314884185791016	gen loss 0.03604525700211525	samples 601/1145
# Training:	epoch 4/25	discr. gan loss 1.4430437088012695	discr. class loss 4.6394243240356445	gen loss 0.03160978853702545	samples 801/1145
# Training:	epoch 4/25	discr. gan loss 1.1247587203979492	discr. class loss 4.086179733276367	gen loss 0.0064454879611730576	samples 1001/1145
# Training:	epoch 4/25	accuracy
#  131
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 4/25	samples 1/407
# Test:	epoch 4/25	samples 51/407
# Test:	epoch 4/25	samples 101/407
# Test:	epoch 4/25	samples 151/407
# Test:	epoch 4/25	samples 201/407
# Test:	epoch 4/25	samples 251/407
# Test:	epoch 4/25	samples 301/407
# Test:	epoch 4/25	samples 351/407
# Test:	epoch 4/25	samples 401/407
# Test:	epoch 4/25	accuracy 2382.0/26032
# Training:	epoch 5/25	discr. gan loss 1.3419219255447388	discr. class loss 4.039218902587891	gen loss 0.07092319428920746	samples 1/1145
# Training:	epoch 5/25	discr. gan loss 1.328704595565796	discr. class loss 0.0	gen loss 0.009442447684705257	samples 201/1145
# Training:	epoch 5/25	discr. gan loss 1.4895670413970947	discr. class loss 4.158912658691406	gen loss 0.036921121180057526	samples 401/1145
# Training:	epoch 5/25	discr. gan loss 1.44166898727417	discr. class loss 0.0	gen loss 0.09608329087495804	samples 601/1145
# Training:	epoch 5/25	discr. gan loss 1.2840957641601562	discr. class loss 0.0	gen loss 0.04985712096095085	samples 801/1145
# Training:	epoch 5/25	discr. gan loss 1.3946958780288696	discr. class loss 0.0	gen loss 0.022466011345386505	samples 1001/1145
# Training:	epoch 5/25	accuracy
#  116
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 5/25	samples 1/407
# Test:	epoch 5/25	samples 51/407
# Test:	epoch 5/25	samples 101/407
# Test:	epoch 5/25	samples 151/407
# Test:	epoch 5/25	samples 201/407
# Test:	epoch 5/25	samples 251/407
# Test:	epoch 5/25	samples 301/407
# Test:	epoch 5/25	samples 351/407
# Test:	epoch 5/25	samples 401/407
# Test:	epoch 5/25	accuracy 2670.0/26032
# Training:	epoch 6/25	discr. gan loss 1.3132776021957397	discr. class loss 0.0	gen loss 0.03901824727654457	samples 1/1145
# Training:	epoch 6/25	discr. gan loss 1.3914849758148193	discr. class loss 4.379976272583008	gen loss 0.005858294665813446	samples 201/1145
# Training:	epoch 6/25	discr. gan loss 1.342336654663086	discr. class loss 0.0	gen loss 0.034256841987371445	samples 401/1145
# Training:	epoch 6/25	discr. gan loss 1.5625219345092773	discr. class loss 4.580175399780273	gen loss 0.10714405030012131	samples 601/1145
# Training:	epoch 6/25	discr. gan loss 1.4644979238510132	discr. class loss 0.0	gen loss 0.008823288604617119	samples 801/1145
# Training:	epoch 6/25	discr. gan loss 1.4132858514785767	discr. class loss 3.9584567546844482	gen loss 0.07996157556772232	samples 1001/1145
# Training:	epoch 6/25	accuracy
#  162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 6/25	samples 1/407
# Test:	epoch 6/25	samples 51/407
# Test:	epoch 6/25	samples 101/407
# Test:	epoch 6/25	samples 151/407
# Test:	epoch 6/25	samples 201/407
# Test:	epoch 6/25	samples 251/407
# Test:	epoch 6/25	samples 301/407
# Test:	epoch 6/25	samples 351/407
# Test:	epoch 6/25	samples 401/407
# Test:	epoch 6/25	accuracy 2847.0/26032
# Training:	epoch 7/25	discr. gan loss 1.4670029878616333	discr. class loss 3.7564525604248047	gen loss 0.02532249316573143	samples 1/1145
# Training:	epoch 7/25	discr. gan loss 1.4007261991500854	discr. class loss 3.9721126556396484	gen loss 0.011066715233027935	samples 201/1145
# Training:	epoch 7/25	discr. gan loss 1.314805030822754	discr. class loss 3.986778497695923	gen loss 0.05097020044922829	samples 401/1145
# Training:	epoch 7/25	discr. gan loss 1.3819423913955688	discr. class loss 3.8827497959136963	gen loss 0.01836075261235237	samples 601/1145
# Training:	epoch 7/25	discr. gan loss 1.3033246994018555	discr. class loss 4.27096700668335	gen loss 0.03577825427055359	samples 801/1145
# Training:	epoch 7/25	discr. gan loss 1.626974105834961	discr. class loss 4.385279655456543	gen loss 0.011898152530193329	samples 1001/1145
# Training:	epoch 7/25	accuracy
#  125
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 7/25	samples 1/407
# Test:	epoch 7/25	samples 51/407
# Test:	epoch 7/25	samples 101/407
# Test:	epoch 7/25	samples 151/407
# Test:	epoch 7/25	samples 201/407
# Test:	epoch 7/25	samples 251/407
# Test:	epoch 7/25	samples 301/407
# Test:	epoch 7/25	samples 351/407
# Test:	epoch 7/25	samples 401/407
# Test:	epoch 7/25	accuracy 3766.0/26032
# Training:	epoch 8/25	discr. gan loss 1.2519246339797974	discr. class loss 0.0	gen loss 0.10382889211177826	samples 1/1145
# Training:	epoch 8/25	discr. gan loss 1.4295177459716797	discr. class loss 4.163241386413574	gen loss 0.04155689477920532	samples 201/1145
# Training:	epoch 8/25	discr. gan loss 1.3167808055877686	discr. class loss 4.477945327758789	gen loss 0.013638991862535477	samples 401/1145
# Training:	epoch 8/25	discr. gan loss 1.2802199125289917	discr. class loss 0.0	gen loss 0.11567524820566177	samples 601/1145
# Training:	epoch 8/25	discr. gan loss 1.4500219821929932	discr. class loss 0.0	gen loss 0.07091886550188065	samples 801/1145
# Training:	epoch 8/25	discr. gan loss 1.3515900373458862	discr. class loss 4.4205217361450195	gen loss 0.06591282784938812	samples 1001/1145
# Training:	epoch 8/25	accuracy
#  125
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 8/25	samples 1/407
# Test:	epoch 8/25	samples 51/407
# Test:	epoch 8/25	samples 101/407
# Test:	epoch 8/25	samples 151/407
# Test:	epoch 8/25	samples 201/407
# Test:	epoch 8/25	samples 251/407
# Test:	epoch 8/25	samples 301/407
# Test:	epoch 8/25	samples 351/407
# Test:	epoch 8/25	samples 401/407
# Test:	epoch 8/25	accuracy 2930.0/26032
# Training:	epoch 9/25	discr. gan loss 1.2906978130340576	discr. class loss 4.114731311798096	gen loss 0.11431729793548584	samples 1/1145
# Training:	epoch 9/25	discr. gan loss 1.4060672521591187	discr. class loss 0.0	gen loss 0.03580688312649727	samples 201/1145
# Training:	epoch 9/25	discr. gan loss 1.356237530708313	discr. class loss 3.94320011138916	gen loss 0.03819182515144348	samples 401/1145
# Training:	epoch 9/25	discr. gan loss 1.4529175758361816	discr. class loss 0.0	gen loss 0.055697061121463776	samples 601/1145
# Training:	epoch 9/25	discr. gan loss 1.3661673069000244	discr. class loss 3.903362274169922	gen loss 0.06176489591598511	samples 801/1145
# Training:	epoch 9/25	discr. gan loss 1.2588717937469482	discr. class loss 4.525590896606445	gen loss 0.0709596648812294	samples 1001/1145
# Training:	epoch 9/25	accuracy
#  131
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 9/25	samples 1/407
# Test:	epoch 9/25	samples 51/407
# Test:	epoch 9/25	samples 101/407
# Test:	epoch 9/25	samples 151/407
# Test:	epoch 9/25	samples 201/407
# Test:	epoch 9/25	samples 251/407
# Test:	epoch 9/25	samples 301/407
# Test:	epoch 9/25	samples 351/407
# Test:	epoch 9/25	samples 401/407
# Test:	epoch 9/25	accuracy 3475.0/26032
# Training:	epoch 10/25	discr. gan loss 1.3072704076766968	discr. class loss 4.207573413848877	gen loss 0.016821108758449554	samples 1/1145
# Training:	epoch 10/25	discr. gan loss 1.3676162958145142	discr. class loss 4.327620983123779	gen loss 0.04052010178565979	samples 201/1145
# Training:	epoch 10/25	discr. gan loss 1.4706321954727173	discr. class loss 4.059563159942627	gen loss 0.04559719190001488	samples 401/1145
# Training:	epoch 10/25	discr. gan loss 1.4374420642852783	discr. class loss 0.0	gen loss 0.06263427436351776	samples 601/1145
# Training:	epoch 10/25	discr. gan loss 1.389106273651123	discr. class loss 3.9187698364257812	gen loss 0.040809616446495056	samples 801/1145
# Training:	epoch 10/25	discr. gan loss 1.4293498992919922	discr. class loss 0.0	gen loss 0.045700788497924805	samples 1001/1145
# Training:	epoch 10/25	accuracy
#  133
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 10/25	samples 1/407
# Test:	epoch 10/25	samples 51/407
# Test:	epoch 10/25	samples 101/407
# Test:	epoch 10/25	samples 151/407
# Test:	epoch 10/25	samples 201/407
# Test:	epoch 10/25	samples 251/407
# Test:	epoch 10/25	samples 301/407
# Test:	epoch 10/25	samples 351/407
# Test:	epoch 10/25	samples 401/407
# Test:	epoch 10/25	accuracy 4149.0/26032
# Training:	epoch 11/25	discr. gan loss 1.375725269317627	discr. class loss 3.9975719451904297	gen loss 0.022560065612196922	samples 1/1145
# Training:	epoch 11/25	discr. gan loss 1.4343702793121338	discr. class loss 4.203137397766113	gen loss 0.0823574885725975	samples 201/1145
# Training:	epoch 11/25	discr. gan loss 1.30076265335083	discr. class loss 0.0	gen loss 0.13351672887802124	samples 401/1145
# Training:	epoch 11/25	discr. gan loss 1.4400620460510254	discr. class loss 4.046949863433838	gen loss 0.07937131077051163	samples 601/1145
# Training:	epoch 11/25	discr. gan loss 1.5288587808609009	discr. class loss 0.0	gen loss 0.05116073414683342	samples 801/1145
# Training:	epoch 11/25	discr. gan loss 1.4105223417282104	discr. class loss 0.0	gen loss 0.16028909385204315	samples 1001/1145
# Training:	epoch 11/25	accuracy
#  110
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 11/25	samples 1/407
# Test:	epoch 11/25	samples 51/407
# Test:	epoch 11/25	samples 101/407
# Test:	epoch 11/25	samples 151/407
# Test:	epoch 11/25	samples 201/407
# Test:	epoch 11/25	samples 251/407
# Test:	epoch 11/25	samples 301/407
# Test:	epoch 11/25	samples 351/407
# Test:	epoch 11/25	samples 401/407
# Test:	epoch 11/25	accuracy 3043.0/26032
# Training:	epoch 12/25	discr. gan loss 1.2473371028900146	discr. class loss 0.0	gen loss 0.033572882413864136	samples 1/1145
# Training:	epoch 12/25	discr. gan loss 1.3482767343521118	discr. class loss 4.721435546875	gen loss 0.02161153219640255	samples 201/1145
# Training:	epoch 12/25	discr. gan loss 1.2864511013031006	discr. class loss 0.0	gen loss 0.036549825221300125	samples 401/1145
# Training:	epoch 12/25	discr. gan loss 1.53326416015625	discr. class loss 0.0	gen loss 0.018265534192323685	samples 601/1145
# Training:	epoch 12/25	discr. gan loss 1.4836499691009521	discr. class loss 0.0	gen loss 0.051499925553798676	samples 801/1145
# Training:	epoch 12/25	discr. gan loss 1.3346099853515625	discr. class loss 3.9218225479125977	gen loss 0.018679646775126457	samples 1001/1145
# Training:	epoch 12/25	accuracy
#  104
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 12/25	samples 1/407
# Test:	epoch 12/25	samples 51/407
# Test:	epoch 12/25	samples 101/407
# Test:	epoch 12/25	samples 151/407
# Test:	epoch 12/25	samples 201/407
# Test:	epoch 12/25	samples 251/407
# Test:	epoch 12/25	samples 301/407
# Test:	epoch 12/25	samples 351/407
# Test:	epoch 12/25	samples 401/407
# Test:	epoch 12/25	accuracy 2770.0/26032
# Training:	epoch 13/25	discr. gan loss 1.456488847732544	discr. class loss 4.3483147621154785	gen loss 0.03448309749364853	samples 1/1145
# Training:	epoch 13/25	discr. gan loss 1.4189236164093018	discr. class loss 0.0	gen loss 0.05524672567844391	samples 201/1145
# Training:	epoch 13/25	discr. gan loss 1.3744897842407227	discr. class loss 0.0	gen loss 0.02252621203660965	samples 401/1145
# Training:	epoch 13/25	discr. gan loss 1.2931534051895142	discr. class loss 4.171027183532715	gen loss 0.07589050382375717	samples 601/1145
# Training:	epoch 13/25	discr. gan loss 1.4312223196029663	discr. class loss 4.4671735763549805	gen loss 0.15115980803966522	samples 801/1145
# Training:	epoch 13/25	discr. gan loss 1.363551139831543	discr. class loss 5.028939247131348	gen loss 0.06173408031463623	samples 1001/1145
# Training:	epoch 13/25	accuracy
#  108
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 13/25	samples 1/407
# Test:	epoch 13/25	samples 51/407
# Test:	epoch 13/25	samples 101/407
# Test:	epoch 13/25	samples 151/407
# Test:	epoch 13/25	samples 201/407
# Test:	epoch 13/25	samples 251/407
# Test:	epoch 13/25	samples 301/407
# Test:	epoch 13/25	samples 351/407
# Test:	epoch 13/25	samples 401/407
# Test:	epoch 13/25	accuracy 4701.0/26032
# Training:	epoch 14/25	discr. gan loss 1.4083640575408936	discr. class loss 4.171032428741455	gen loss 0.051979515701532364	samples 1/1145
# Training:	epoch 14/25	discr. gan loss 1.4514915943145752	discr. class loss 4.303254127502441	gen loss 0.03717741742730141	samples 201/1145
# Training:	epoch 14/25	discr. gan loss 1.3878905773162842	discr. class loss 3.940354585647583	gen loss 0.024877268821001053	samples 401/1145
# Training:	epoch 14/25	discr. gan loss 1.347612977027893	discr. class loss 0.0	gen loss 0.10193660110235214	samples 601/1145
# Training:	epoch 14/25	discr. gan loss 1.4303020238876343	discr. class loss 3.414659261703491	gen loss 0.1588197648525238	samples 801/1145
# Training:	epoch 14/25	discr. gan loss 1.257859468460083	discr. class loss 4.277451038360596	gen loss 0.11110575497150421	samples 1001/1145
# Training:	epoch 14/25	accuracy
#  158
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 14/25	samples 1/407
# Test:	epoch 14/25	samples 51/407
# Test:	epoch 14/25	samples 101/407
# Test:	epoch 14/25	samples 151/407
# Test:	epoch 14/25	samples 201/407
# Test:	epoch 14/25	samples 251/407
# Test:	epoch 14/25	samples 301/407
# Test:	epoch 14/25	samples 351/407
# Test:	epoch 14/25	samples 401/407
# Test:	epoch 14/25	accuracy 3550.0/26032
# Training:	epoch 15/25	discr. gan loss 1.3243141174316406	discr. class loss 3.6084587574005127	gen loss 0.13342446088790894	samples 1/1145
# Training:	epoch 15/25	discr. gan loss 1.368552565574646	discr. class loss 0.0	gen loss 0.10935953259468079	samples 201/1145
# Training:	epoch 15/25	discr. gan loss 1.4175546169281006	discr. class loss 4.135586738586426	gen loss 0.057602692395448685	samples 401/1145
# Training:	epoch 15/25	discr. gan loss 1.3418344259262085	discr. class loss 4.157942771911621	gen loss 0.07148955762386322	samples 601/1145
# Training:	epoch 15/25	discr. gan loss 1.318383812904358	discr. class loss 0.0	gen loss 0.03898703679442406	samples 801/1145
# Training:	epoch 15/25	discr. gan loss 1.4493612051010132	discr. class loss 0.0	gen loss 0.10663457214832306	samples 1001/1145
# Training:	epoch 15/25	accuracy
#  168
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 15/25	samples 1/407
# Test:	epoch 15/25	samples 51/407
# Test:	epoch 15/25	samples 101/407
# Test:	epoch 15/25	samples 151/407
# Test:	epoch 15/25	samples 201/407
# Test:	epoch 15/25	samples 251/407
# Test:	epoch 15/25	samples 301/407
# Test:	epoch 15/25	samples 351/407
# Test:	epoch 15/25	samples 401/407
# Test:	epoch 15/25	accuracy 4976.0/26032
# Training:	epoch 16/25	discr. gan loss 1.5013920068740845	discr. class loss 4.3205413818359375	gen loss 0.12568318843841553	samples 1/1145
# Training:	epoch 16/25	discr. gan loss 1.3746978044509888	discr. class loss 4.177976608276367	gen loss 0.0572376623749733	samples 201/1145
# Training:	epoch 16/25	discr. gan loss 1.3388123512268066	discr. class loss 4.295416355133057	gen loss 0.14125360548496246	samples 401/1145
# Training:	epoch 16/25	discr. gan loss 1.4670771360397339	discr. class loss 4.162466049194336	gen loss 0.02852049469947815	samples 601/1145
# Training:	epoch 16/25	discr. gan loss 1.4075077772140503	discr. class loss 4.255580425262451	gen loss 0.15178871154785156	samples 801/1145
# Training:	epoch 16/25	discr. gan loss 1.3709180355072021	discr. class loss 4.488859176635742	gen loss 0.09578351676464081	samples 1001/1145
# Training:	epoch 16/25	accuracy
#  192
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 16/25	samples 1/407
# Test:	epoch 16/25	samples 51/407
# Test:	epoch 16/25	samples 101/407
# Test:	epoch 16/25	samples 151/407
# Test:	epoch 16/25	samples 201/407
# Test:	epoch 16/25	samples 251/407
# Test:	epoch 16/25	samples 301/407
# Test:	epoch 16/25	samples 351/407
# Test:	epoch 16/25	samples 401/407
# Test:	epoch 16/25	accuracy 3998.0/26032
# Training:	epoch 17/25	discr. gan loss 1.539011001586914	discr. class loss 3.3757946491241455	gen loss 0.055655594915151596	samples 1/1145
# Training:	epoch 17/25	discr. gan loss 1.235562801361084	discr. class loss 4.366891860961914	gen loss 0.08132532984018326	samples 201/1145
# Training:	epoch 17/25	discr. gan loss 1.3518049716949463	discr. class loss 0.0	gen loss 0.08534541726112366	samples 401/1145
# Training:	epoch 17/25	discr. gan loss 1.3992128372192383	discr. class loss 3.6269845962524414	gen loss 0.12610876560211182	samples 601/1145
# Training:	epoch 17/25	discr. gan loss 1.3425662517547607	discr. class loss 3.5223097801208496	gen loss 0.03393036872148514	samples 801/1145
# Training:	epoch 17/25	discr. gan loss 1.3402214050292969	discr. class loss 0.0	gen loss 0.04743899032473564	samples 1001/1145
# Training:	epoch 17/25	accuracy
#  174
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 17/25	samples 1/407
# Test:	epoch 17/25	samples 51/407
# Test:	epoch 17/25	samples 101/407
# Test:	epoch 17/25	samples 151/407
# Test:	epoch 17/25	samples 201/407
# Test:	epoch 17/25	samples 251/407
# Test:	epoch 17/25	samples 301/407
# Test:	epoch 17/25	samples 351/407
# Test:	epoch 17/25	samples 401/407
# Test:	epoch 17/25	accuracy 4420.0/26032
# Training:	epoch 18/25	discr. gan loss 1.2907347679138184	discr. class loss 4.046289443969727	gen loss 0.11702729761600494	samples 1/1145
# Training:	epoch 18/25	discr. gan loss 1.3344776630401611	discr. class loss 4.075083255767822	gen loss 0.04956687241792679	samples 201/1145
# Training:	epoch 18/25	discr. gan loss 1.4527292251586914	discr. class loss 4.2489542961120605	gen loss 0.062062107026576996	samples 401/1145
# Training:	epoch 18/25	discr. gan loss 1.3741984367370605	discr. class loss 0.0	gen loss 0.08018766343593597	samples 601/1145
# Training:	epoch 18/25	discr. gan loss 1.4074161052703857	discr. class loss 4.043986797332764	gen loss 0.05247121676802635	samples 801/1145
# Training:	epoch 18/25	discr. gan loss 1.3132038116455078	discr. class loss 3.9517500400543213	gen loss 0.06686362624168396	samples 1001/1145
# Training:	epoch 18/25	accuracy
#  215
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 18/25	samples 1/407
# Test:	epoch 18/25	samples 51/407
# Test:	epoch 18/25	samples 101/407
# Test:	epoch 18/25	samples 151/407
# Test:	epoch 18/25	samples 201/407
# Test:	epoch 18/25	samples 251/407
# Test:	epoch 18/25	samples 301/407
# Test:	epoch 18/25	samples 351/407
# Test:	epoch 18/25	samples 401/407
# Test:	epoch 18/25	accuracy 5134.0/26032
# Training:	epoch 19/25	discr. gan loss 1.2473020553588867	discr. class loss 0.0	gen loss 0.12305793166160583	samples 1/1145
# Training:	epoch 19/25	discr. gan loss 1.244723916053772	discr. class loss 4.6545491218566895	gen loss 0.16460926830768585	samples 201/1145
# Training:	epoch 19/25	discr. gan loss 1.2895585298538208	discr. class loss 0.0	gen loss 0.08594854921102524	samples 401/1145
# Training:	epoch 19/25	discr. gan loss 1.2369005680084229	discr. class loss 4.121493816375732	gen loss 0.04079688712954521	samples 601/1145
# Training:	epoch 19/25	discr. gan loss 1.2959508895874023	discr. class loss 0.0	gen loss 0.0539422370493412	samples 801/1145
# Training:	epoch 19/25	discr. gan loss 1.3088146448135376	discr. class loss 0.0	gen loss 0.08852871507406235	samples 1001/1145
# Training:	epoch 19/25	accuracy
#  226
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 19/25	samples 1/407
# Test:	epoch 19/25	samples 51/407
# Test:	epoch 19/25	samples 101/407
# Test:	epoch 19/25	samples 151/407
# Test:	epoch 19/25	samples 201/407
# Test:	epoch 19/25	samples 251/407
# Test:	epoch 19/25	samples 301/407
# Test:	epoch 19/25	samples 351/407
# Test:	epoch 19/25	samples 401/407
# Test:	epoch 19/25	accuracy 5257.0/26032
# Training:	epoch 20/25	discr. gan loss 1.1904830932617188	discr. class loss 4.166511535644531	gen loss 0.10951148718595505	samples 1/1145
# Training:	epoch 20/25	discr. gan loss 1.3270877599716187	discr. class loss 0.0	gen loss 0.0926639661192894	samples 201/1145
# Training:	epoch 20/25	discr. gan loss 1.2230417728424072	discr. class loss 4.753193378448486	gen loss 0.08542226999998093	samples 401/1145
# Training:	epoch 20/25	discr. gan loss 1.392181396484375	discr. class loss 2.1964101791381836	gen loss 0.11667664349079132	samples 601/1145
# Training:	epoch 20/25	discr. gan loss 1.2676982879638672	discr. class loss 0.0	gen loss 0.09506774693727493	samples 801/1145
# Training:	epoch 20/25	discr. gan loss 1.2589434385299683	discr. class loss 4.076793193817139	gen loss 0.1852649599313736	samples 1001/1145
# Training:	epoch 20/25	accuracy
#  230
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 20/25	samples 1/407
# Test:	epoch 20/25	samples 51/407
# Test:	epoch 20/25	samples 101/407
# Test:	epoch 20/25	samples 151/407
# Test:	epoch 20/25	samples 201/407
# Test:	epoch 20/25	samples 251/407
# Test:	epoch 20/25	samples 301/407
# Test:	epoch 20/25	samples 351/407
# Test:	epoch 20/25	samples 401/407
# Test:	epoch 20/25	accuracy 5772.0/26032
# Training:	epoch 21/25	discr. gan loss 1.1430330276489258	discr. class loss 0.0	gen loss 0.0376519039273262	samples 1/1145
# Training:	epoch 21/25	discr. gan loss 1.294316053390503	discr. class loss 0.0	gen loss 0.08559367060661316	samples 201/1145
# Training:	epoch 21/25	discr. gan loss 1.196150302886963	discr. class loss 2.2674667835235596	gen loss 0.05183137208223343	samples 401/1145
# Training:	epoch 21/25	discr. gan loss 1.27617609500885	discr. class loss 1.7474318742752075	gen loss 0.1386565864086151	samples 601/1145
# Training:	epoch 21/25	discr. gan loss 1.1114965677261353	discr. class loss 4.426078796386719	gen loss 0.053369879722595215	samples 801/1145
# Training:	epoch 21/25	discr. gan loss 1.2882754802703857	discr. class loss 4.254964828491211	gen loss 0.07254205644130707	samples 1001/1145
# Training:	epoch 21/25	accuracy
#  238
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 21/25	samples 1/407
# Test:	epoch 21/25	samples 51/407
# Test:	epoch 21/25	samples 101/407
# Test:	epoch 21/25	samples 151/407
# Test:	epoch 21/25	samples 201/407
# Test:	epoch 21/25	samples 251/407
# Test:	epoch 21/25	samples 301/407
# Test:	epoch 21/25	samples 351/407
# Test:	epoch 21/25	samples 401/407
# Test:	epoch 21/25	accuracy 5633.0/26032
# Training:	epoch 22/25	discr. gan loss 1.2362542152404785	discr. class loss 0.0	gen loss 0.11951269209384918	samples 1/1145
# Training:	epoch 22/25	discr. gan loss 1.3498666286468506	discr. class loss 4.264256000518799	gen loss 0.12117844820022583	samples 201/1145
# Training:	epoch 22/25	discr. gan loss 1.2507274150848389	discr. class loss 0.0	gen loss 0.21754196286201477	samples 401/1145
# Training:	epoch 22/25	discr. gan loss 1.3382362127304077	discr. class loss 3.3095459938049316	gen loss 0.06230875477194786	samples 601/1145
# Training:	epoch 22/25	discr. gan loss 1.2295552492141724	discr. class loss 3.6986329555511475	gen loss 0.10983087122440338	samples 801/1145
# Training:	epoch 22/25	discr. gan loss 1.119737982749939	discr. class loss 3.3590333461761475	gen loss 0.11671645194292068	samples 1001/1145
# Training:	epoch 22/25	accuracy
#  229
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 22/25	samples 1/407
# Test:	epoch 22/25	samples 51/407
# Test:	epoch 22/25	samples 101/407
# Test:	epoch 22/25	samples 151/407
# Test:	epoch 22/25	samples 201/407
# Test:	epoch 22/25	samples 251/407
# Test:	epoch 22/25	samples 301/407
# Test:	epoch 22/25	samples 351/407
# Test:	epoch 22/25	samples 401/407
# Test:	epoch 22/25	accuracy 4875.0/26032
# Training:	epoch 23/25	discr. gan loss 1.3359049558639526	discr. class loss 0.0	gen loss 0.10710684955120087	samples 1/1145
# Training:	epoch 23/25	discr. gan loss 1.2450851202011108	discr. class loss 3.5213963985443115	gen loss 0.07720927149057388	samples 201/1145
# Training:	epoch 23/25	discr. gan loss 1.239417552947998	discr. class loss 4.003139019012451	gen loss 0.11084828525781631	samples 401/1145
# Training:	epoch 23/25	discr. gan loss 1.3310246467590332	discr. class loss 4.027710437774658	gen loss 0.13232600688934326	samples 601/1145
# Training:	epoch 23/25	discr. gan loss 1.2589635848999023	discr. class loss 4.224597930908203	gen loss 0.15268854796886444	samples 801/1145
# Training:	epoch 23/25	discr. gan loss 1.3364300727844238	discr. class loss 0.0	gen loss 0.09850876778364182	samples 1001/1145
# Training:	epoch 23/25	accuracy
#  225
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 23/25	samples 1/407
# Test:	epoch 23/25	samples 51/407
# Test:	epoch 23/25	samples 101/407
# Test:	epoch 23/25	samples 151/407
# Test:	epoch 23/25	samples 201/407
# Test:	epoch 23/25	samples 251/407
# Test:	epoch 23/25	samples 301/407
# Test:	epoch 23/25	samples 351/407
# Test:	epoch 23/25	samples 401/407
# Test:	epoch 23/25	accuracy 4976.0/26032
# Training:	epoch 24/25	discr. gan loss 1.3487129211425781	discr. class loss 0.0	gen loss 0.09126138687133789	samples 1/1145
# Training:	epoch 24/25	discr. gan loss 1.182968020439148	discr. class loss 4.258074760437012	gen loss 0.051427897065877914	samples 201/1145
# Training:	epoch 24/25	discr. gan loss 1.1403110027313232	discr. class loss 5.420524597167969	gen loss 0.16291387379169464	samples 401/1145
# Training:	epoch 24/25	discr. gan loss 1.2108713388442993	discr. class loss 2.6740498542785645	gen loss 0.2529546320438385	samples 601/1145
# Training:	epoch 24/25	discr. gan loss 1.2348544597625732	discr. class loss 0.0	gen loss 0.10873515158891678	samples 801/1145
# Training:	epoch 24/25	discr. gan loss 0.8969669342041016	discr. class loss 0.0	gen loss 0.15750239789485931	samples 1001/1145
# Training:	epoch 24/25	accuracy
#  229
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 24/25	samples 1/407
# Test:	epoch 24/25	samples 51/407
# Test:	epoch 24/25	samples 101/407
# Test:	epoch 24/25	samples 151/407
# Test:	epoch 24/25	samples 201/407
# Test:	epoch 24/25	samples 251/407
# Test:	epoch 24/25	samples 301/407
# Test:	epoch 24/25	samples 351/407
# Test:	epoch 24/25	samples 401/407
# Test:	epoch 24/25	accuracy 4565.0/26032
# Training:	epoch 25/25	discr. gan loss 0.9783506393432617	discr. class loss 0.0	gen loss 0.07777618616819382	samples 1/1145
# Training:	epoch 25/25	discr. gan loss 1.5670874118804932	discr. class loss 2.666698455810547	gen loss 0.15992112457752228	samples 201/1145
# Training:	epoch 25/25	discr. gan loss 0.9292961955070496	discr. class loss 0.0	gen loss 0.12985530495643616	samples 401/1145
# Training:	epoch 25/25	discr. gan loss 1.3314220905303955	discr. class loss 0.0	gen loss 0.07025304436683655	samples 601/1145
# Training:	epoch 25/25	discr. gan loss 1.268809199333191	discr. class loss 3.0363144874572754	gen loss 0.10961543023586273	samples 801/1145
# Training:	epoch 25/25	discr. gan loss 1.1776748895645142	discr. class loss 3.7675716876983643	gen loss 0.16366754472255707	samples 1001/1145
# Training:	epoch 25/25	accuracy
#  173
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# /
#  1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Test:	epoch 25/25	samples 1/407
# Test:	epoch 25/25	samples 51/407
# Test:	epoch 25/25	samples 101/407
# Test:	epoch 25/25	samples 151/407
# Test:	epoch 25/25	samples 201/407
# Test:	epoch 25/25	samples 251/407
# Test:	epoch 25/25	samples 301/407
# Test:	epoch 25/25	samples 351/407
# Test:	epoch 25/25	samples 401/407
# Test:	epoch 25/25	accuracy 2665.0/26032
